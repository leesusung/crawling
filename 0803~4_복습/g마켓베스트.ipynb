# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
url = 'http://corners.gmarket.co.kr/Bestsellers'

# %%
response = requests.get(url)

# %%
response.text[:300]
# Out:
# '<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">\r\n<html lang="ko">\r\n<head>\r\n\t<title>G마켓 - G마켓 베스트</title>\r\n\t<meta http-equiv="X-UA-Compatible" content="IE=edge" />\r\n\t<meta http-equiv="content-type" content="text/html; charset=utf-8" />\r\n\t<meta ht'

# %%
dom=BeautifulSoup(response.text , 'html.parser')

# %%
elements=dom.select("#gBestWrap > div > div:nth-child(5) > div > ul> li")

# %%
len(elements)

element=elements[0]

# %%
element
# Out:
# <li class="first">
# <p class="no1" id="no1">1</p>
# <div class="thumb">
# <a href="http://item.gmarket.co.kr/Item?goodscode=1798110680&amp;ver=637952529594405767" onclick="pdsClickLog('200000680', 'Item', {'ASN': 1, 'goodsCode': '1798110680'});"><img alt="[한상궁김치]한상궁김치 국산 겉절이 2kg 출고당일생산" class="lazy" data-original="//gdimg.gmarket.co.kr/1798110680/still/300?ver=2022080423" height="210" src="//image.gmarket.co.kr/challenge/neo_image/no_image.gif" width="210"/></a>
# </div>
# <!--div class="goods-view">
# 									<a href="http://minishop.gmarket.co.kr/hansanggungfood"><span class="view">판매자 다른상품 보기</span>맛있는한상궁</a>
# 								</div-->
# <a class="itemname" href="http://item.gmarket.co.kr/Item?goodscode=1798110680&amp;ver=637952529594405767" onclick="pdsClickLog('200000680', 'Item', {'ASN': 1, 'goodsCode': '1798110680'});">[한상궁김치]한상궁김치 국산 겉절이 2kg 출고당일생산</a>
# <div class="item_price">
# <div class="o-price"><span><span>23,400원</span></span></div>
# <div class="s-price">
# ...

# %%
#gBestWrap > div > div:nth-child(5) > div > ul > li:nth-child(1)
#gBestWrap > div > div:nth-child(5) > div > ul
#gBestWrap > div > div:nth-child(5) > div > ul > li

# %%
data= {
    'name' : element.select_one(".itemname").text,
    'price_x' : element.select_one(".o-price").text,
    'price' : element.select_one(".s-price > strong").text,
}

# %%
data
# Out:
# {'name': '[한상궁김치]한상궁김치 국산 겉절이 2kg 출고당일생산',
#  'price_x': '23,400원',
#  'price': '11,000원'}

# %%
items = []

for element in elements:
    data= {
    'name' : element.select_one(".itemname").text,
    'price_x' : element.select_one(".o-price").text,
    'price' : element.select_one(".s-price > strong").text,
    }
    items.append(data)

# %%
items
# Out:
# [{'name': '[한상궁김치]한상궁김치 국산 겉절이 2kg 출고당일생산',
#   'price_x': '23,400원',
#   'price': '11,000원'},
#  {'name': '(쌀가게) (광주신세계)[주문폭증으로 순차적 출고 예정] [2021년 햅쌀] 쌀가게  수향미 (특등급 )10KG',
#   'price_x': '33,900원',
#   'price': '28,140원'},
#  {'name': '[광동]아이스웨일 레몬라임 탄산수 500ml 40pet/음료/음료수',
#   'price_x': '17,300원',
#   'price': '13,900원'},
#  {'name': '[바디스토리]남성 누디5매 냉감 쿨 드로즈 남자 아이스 사각 팬티 / 무료반품+10%+15%할인',
#   'price_x': '39,600원',
#   'price': '11,900원'},
#  {'name': '남도장터 정남진농협 장흥 새청무 10kg 상등급',
#   'price_x': '39,900원',
#   'price': '25,500원'},
#  {'name': '[네파키즈][네파키즈(아동)] 리버서블 헤비 구스 다운 KHF2007',
#   'price_x': '109,000원',
#   'price': '75,210원'},
#  {'name': '[이너리즘](10%+12%쿠폰) 심리스 스포츠 브라탑 4장기획세트/노라인팬티 5종',
#   'price_x': '43,000원',
#   'price': '12,900원'},
#  {'name': '[크리넥스]순수 3겹 두루마리 화장지 휴지 27m 24롤 2팩',
#   'price_x': '',
#   'price': '30,000원'},
#  {'name': '[플레이보이]남성 남자 패키지 드로즈 10매입 세트 PMD2109+2110B / 무료반품+10%+15%할인',
#   'price_x': '99,660원',
#   'price': '29,900원'},
# ...

# %%
pd.DataFrame(items)
# Out:
#                                                   name  price_x    price
# 0                       [한상궁김치]한상궁김치 국산 겉절이 2kg 출고당일생산  23,400원  11,000원
# 1    (쌀가게) (광주신세계)[주문폭증으로 순차적 출고 예정] [2021년 햅쌀] 쌀가게...  33,900원  28,140원
# 2                [광동]아이스웨일 레몬라임 탄산수 500ml 40pet/음료/음료수  17,300원  13,900원
# 3    [바디스토리]남성 누디5매 냉감 쿨 드로즈 남자 아이스 사각 팬티 / 무료반품+10...  39,600원  11,900원
# 4                           남도장터 정남진농협 장흥 새청무 10kg 상등급  39,900원  25,500원
# ..                                                 ...      ...      ...
# 195                     [순수당]순수당 국산벌꿀 대용량튜브2kg/야생화/사양꿀           14,600원
# 196                            [베베숲]베베숲 프리미어 70매 캡 20팩  42,800원  28,900원
# 197                  아오리 보다 맛있는 썸머킹 4.5KG 25~30과 내외 소과           10,900원
# 198                   [오뚜기밥]오뚜기 맛있는 밥 20입(210g10 x 2개)           21,900원
# 199                              클럽클리오 월간 클리오 8월호 ~48%  44,000원  19,600원
#
# [200 rows x 3 columns]
