# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
size= 20
date=20220814
url =f'https://m.stock.naver.com/api/stock/225570/trend?pageSize={size}&bizdate={date}'

# %%
response=requests.get(url)

# %%
data=response.json()

# %%
bizdate ,closePrice
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14544/945446092.py in <module>
# ----> 1 bizdate ,closePrice
#
# NameError: name 'bizdate' is not defined

# %%
pd.DataFrame(data)[['bizdate','closePrice']]
# Out:
#      bizdate closePrice
# 0   20220812          -
# 1   20220811     22,100
# 2   20220810     21,900
# 3   20220809     21,950
# 4   20220808     22,000
# 5   20220805     22,200
# 6   20220804     22,950
# 7   20220803     23,000
# 8   20220802     22,300
# 9   20220801     22,300
# 10  20220729     22,550
# 11  20220728     22,150
# 12  20220727     20,900
# 13  20220726     19,750
# 14  20220725     19,500
# 15  20220722     19,700
# 16  20220721     20,600
# 17  20220720     20,250
# 18  20220719     20,350
# 19  20220718     20,350

# %%
url = 'https://cookatmarket.com/ko/main/best?page=1&sort=2&category_filter=31&cookat_delivery=N'

# %%
response = requests.get(url)

# %%
response.text[:300]
# Out:
# '<!DOCTYPE html>\n<html lang="en" class="web">\n<head>\n    <title>쿠캣</title>\n    <meta charset="utf-8">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n    <meta http-equiv="Content-Type" content="text/html; charset=UTF-8">\n    <!-- for Mobile Meta -->\n    <meta content="width=device-width, h'

# %%
dom=BeautifulSoup(response.text , 'html.parser')

# %%
elements=dom.select('#main_best_product_container > ul')

# %%
#main_best_product_container > ul

# %%
element=elements[0]

# %%
element
# Out:
# <ul class="type1-product-wrap">
# <li class="type1-product-item" data-product="337">
# <div class="type1-product-image-wrap">
# <div class="label-box">
# </div>
# <a class="product-image" href="/ko/product/detail?product_id=337">
# <img onerror="this.src='https://crcf.cookatmarket.com/icons/cookatmarket_no_image.svg'" src="https://crcf.cookatmarket.com/product/images/2019/11/lisa_1574236035_2614_320.jpg"/>
# </a>
# <a class="quick-cart" onclick="openQuickPurchase(this, 337);">
# <img src="https://crcf.cookatmarket.com/assets/mobile/img/using_guide/ic-cart-bg-40.svg"/>
# </a>
# </div>
# <div class="type1-product-info-wrap">
# <a class="type1-product-info" href="/ko/product/detail?product_id=337">
# <div class="type1-product-name cc-clr-gb cc-fs-14 ellipsis-2">쿠캣 쿠가네 감자탕 2.5kg</div>
# <div class="type1-product-price">
# <span class="selling-price cc-fs-16 cc-clr-gb cc-pretendard-r"><strong class="cc-pretendard-b">16,900</strong>원</span>
# </div>
# </a>
# ...

# %%
data= {
    'name' : element.select_one("type1-product-name cc-clr-gb cc-fs-14 ellipsis-2").text,
    'price_x' : element.select_one("cc-pretendard-b").text,
}
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14544/4028096165.py in <module>
#       1 data= {
# ----> 2     'name' : element.select_one("type1-product-name cc-clr-gb cc-fs-14 ellipsis-2").text,
#       3     'price_x' : element.select_one("cc-pretendard-b").text,
#       4 }
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
elements.select_one("type1-product-name cc-clr-gb cc-fs-14 ellipsis-2").text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14544/523209910.py in <module>
# ----> 1 elements.select_one("type1-product-name cc-clr-gb cc-fs-14 ellipsis-2").text
#
# c:\Users\susung05\anaconda3\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    2251     def __getattr__(self, key):
#    2252         """Raise a helpful exception to explain a common code fix."""
# -> 2253         raise AttributeError(
#    2254             "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2255         )
#
# AttributeError: ResultSet object has no attribute 'select_one'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
element.select_one("sticker sticker-cd").text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14544/3479183733.py in <module>
# ----> 1 element.select_one("sticker sticker-cd").text
#
# AttributeError: 'NoneType' object has no attribute 'text'
